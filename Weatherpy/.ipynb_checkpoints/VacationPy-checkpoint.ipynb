# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head(60)
# Out:
#     City_ID                                  City      Lat       Lng  \
# 0         0                              waitangi -43.9535 -176.5597
# 1         1                        ribeira grande  38.5167  -28.7000
# 2         2                           olonkinbyen  70.9221   -8.7187
# 3         3                             adamstown -25.0660 -130.1015
# 4         4                             grytviken -54.2811  -36.5092
# 5         5                            vila velha -20.3297  -40.2925
# 6         6                     port-aux-francais -49.3500   70.2167
# 7         7                         blackmans bay -43.0167  147.3167
# 8         8                       varzea da palma -17.5981  -44.7308
# 9         9                              enewetak  11.3474  162.3373
# 10       10                            port blair  11.6667   92.7500
# 11       11                           west island -12.1568   96.8225
# 12       12                               chonchi -42.6128  -73.8092
# ...

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
city_data_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 0          0                waitangi -43.9535 -176.5597    283.05        95
# 1          1          ribeira grande  38.5167  -28.7000    294.14        77
# 2          2             olonkinbyen  70.9221   -8.7187    274.98        77
# 3          3               adamstown -25.0660 -130.1015    293.15        76
# 4          4               grytviken -54.2811  -36.5092    272.59        67
# ..       ...                     ...      ...       ...       ...       ...
# 569      569  sao miguel do araguaia -13.2750  -50.1628    308.01        35
# 570      570             el calafate -50.3408  -72.2768    278.19        85
# 571      571                     lae  -6.7221  146.9847    295.96        85
# 572      572               kigonsera -10.8000   35.0500    292.60        53
# 573      573                    daru  -9.0763  143.2092    297.87        79
#
#      Cloudiness  Wind Speed Country        Date
# ...

# %%
# Define conditions for filtering
# Convert temperature from Kelvin to Celsius
city_data_df['Max Temp (°C)'] = city_data_df['Max Temp'] - 273.15

# Define conditions for filtering
max_temp_condition = city_data_df['Max Temp (°C)'] < 25  # Maximum temperature less than 25°C
humidity_condition = city_data_df['Humidity'] < 50  # Humidity less than 50%
cloudiness_condition = city_data_df['Cloudiness'] < 30  # Cloudiness less than 30%
wind_speed_condition = city_data_df['Wind Speed'] < 10  # Wind speed less than 10 m/s

# Filter cities based on conditions
narrowed_city_df = city_data_df[max_temp_condition & humidity_condition & cloudiness_condition & wind_speed_condition]

# Drop any rows with null values
narrowed_city_df = narrowed_city_df.dropna(how='any')

# Reset index
narrowed_city_df.reset_index(drop=True, inplace=True)

# Display sample data
narrowed_city_df
# Out:
#     City_ID                     City      Lat       Lng  Max Temp  Humidity  \
# 0        13                   forest  37.3638  -79.2897    292.55        43
# 1        29                    crane  31.3974 -102.3501    295.29        31
# 2        31      saint-jean-de-monts  46.7833   -2.0667    293.29        46
# 3        82            mar del plata -38.0023  -57.5575    294.16        23
# 4       104               laojunmiao  39.8333   97.7333    280.25        35
# 5       123                   jasper  37.2001  -94.3502    291.30        42
# 6       137                rock hill  34.9249  -81.0251    296.92        32
# 7       145                   harnai  30.1005   67.9374    297.13        13
# 8       194  homestead meadows south  31.8110 -106.1643    297.59        33
# 9       223                kununurra -15.7667  128.7333    298.14        25
# 10      237                  socorro  31.6546 -106.3033    298.07        34
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = narrowed_city_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''


# Display sample data
hotel_df.head()
# Out:
#                   City Country      Lat       Lng  Humidity Hotel Name
# 0               forest      US  37.3638  -79.2897        43
# 1                crane      US  31.3974 -102.3501        31
# 2  saint-jean-de-monts      FR  46.7833   -2.0667        46
# 3        mar del plata      AR -38.0023  -57.5575        23
# 4           laojunmiao      CN  39.8333   97.7333        35

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']

    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address =  response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# forest - nearest hotel: Tru by Hilton Lynchburg
# crane - nearest hotel: No hotel found
# saint-jean-de-monts - nearest hotel: L'Espadon
# mar del plata - nearest hotel: Nuevo Ostende
# laojunmiao - nearest hotel: No hotel found
# jasper - nearest hotel: Econo Lodge
# rock hill - nearest hotel: Cambria Hotel Rock Hill - University Center
# harnai - nearest hotel: No hotel found
# homestead meadows south - nearest hotel: Tru By Hilton El Paso
# kununurra - nearest hotel: Kununurra Country Club Resort
# socorro - nearest hotel: Courtyard by Marriott
# la passe - nearest hotel: L'Estuaire
# kansanshi - nearest hotel: Paka Lodge
# san angelo - nearest hotel: Hilton Hotel
# creston - nearest hotel: No hotel found
# vallenar - nearest hotel: Hotel del Marqués
# argostolion - nearest hotel: Ainos Hotel
# brak - nearest hotel: فندق براك السياحي
# lupane - nearest hotel: No hotel found
# dawson creek - nearest hotel: Comfort Inn
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    hover_cols = ["Hotel Name", "Country"],
    frame_width = 700,
    frame_height = 500
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)

# %%
# %%capture --no-display

# Configure the map plot
hotel_plot =hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo = True, 
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha = 0.5,
    tiles = "OSM",
    hover_cols = ["Hotel Name", "Country"],
    frame_width = 700,
    frame_height = 500
)

# Display the map
hotel_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
