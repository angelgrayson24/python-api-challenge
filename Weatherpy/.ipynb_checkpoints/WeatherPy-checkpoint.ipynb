# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?unit=Metric&appid=" + weather_api_key
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
     

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | waitangi
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | olonkinbyen
# Processing Record 4 of Set 1 | adamstown
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | vila velha
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | blackmans bay
# Processing Record 9 of Set 1 | varzea da palma
# Processing Record 10 of Set 1 | enewetak
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | west island
# Processing Record 13 of Set 1 | chonchi
# Processing Record 14 of Set 1 | forest
# Processing Record 15 of Set 1 | saipan
# Processing Record 16 of Set 1 | ust-nera
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | isafjordur
# Processing Record 19 of Set 1 | salinas
# Processing Record 20 of Set 1 | mount isa
# Processing Record 21 of Set 1 | st. john's
# Processing Record 22 of Set 1 | utrik
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | mendes
# Processing Record 26 of Set 1 | deqing
# Processing Record 27 of Set 1 | lisala
# Processing Record 28 of Set 1 | puerto natales
# Processing Record 29 of Set 1 | broken hill
# Processing Record 30 of Set 1 | crane
# Processing Record 31 of Set 1 | hadibu
# Processing Record 32 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 33 of Set 1 | saint-jean-de-monts
# Processing Record 34 of Set 1 | afaahiti
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | la mira
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | tolanaro
# Processing Record 39 of Set 1 | port lincoln
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | acapulco de juarez
# Processing Record 42 of Set 1 | zapolyarnyy
# Processing Record 43 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 44 of Set 1 | tiksi
# Processing Record 45 of Set 1 | severo-yeniseyskiy
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | sejenane
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | avarua
# Processing Record 50 of Set 1 | guasdualito
# Processing Record 0 of Set 2 | atafu village
# Processing Record 1 of Set 2 | mount pearl
# Processing Record 2 of Set 2 | antonio enes
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | weno
# Processing Record 5 of Set 2 | hengchun
# Processing Record 6 of Set 2 | laem sing
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | edinburgh of the seven seas
# Processing Record 9 of Set 2 | palikir - national government center
# Processing Record 10 of Set 2 | berdigestyakh
# Processing Record 11 of Set 2 | bethel
# Processing Record 12 of Set 2 | college
# Processing Record 13 of Set 2 | invercargill
# Processing Record 14 of Set 2 | hami
# Processing Record 15 of Set 2 | harstad
# Processing Record 16 of Set 2 | maladziecna
# City not found. Skipping...
# Processing Record 4 of Set 5 | awash
# Processing Record 5 of Set 5 | kalaleh
# Processing Record 6 of Set 5 | minas de marcona
# Processing Record 7 of Set 5 | bilibino
# Processing Record 8 of Set 5 | barra dos coqueiros
# Processing Record 9 of Set 5 | ancud
# Processing Record 10 of Set 5 | mohale's hoek
# Processing Record 11 of Set 5 | ola
# Processing Record 12 of Set 5 | merizo village
# Processing Record 13 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | wynyard
# Processing Record 18 of Set 5 | roccella ionica
# Processing Record 19 of Set 5 | castillos
# Processing Record 20 of Set 5 | ust'-ilimsk
# Processing Record 21 of Set 5 | thunder bay
# Processing Record 22 of Set 5 | ujae
# Processing Record 23 of Set 5 | vilyuchinsk
# Processing Record 24 of Set 5 | sao joao da barra
# Processing Record 25 of Set 5 | papatowai
# Processing Record 26 of Set 5 | port saint john's
# Processing Record 27 of Set 5 | nuuk
# Processing Record 28 of Set 5 | barreirinhas
# Processing Record 29 of Set 5 | el alto
# Processing Record 30 of Set 5 | kununurra
# Processing Record 31 of Set 5 | al mayadin
# Processing Record 32 of Set 5 | tura
# Processing Record 33 of Set 5 | luderitz
# Processing Record 34 of Set 5 | burang
# Processing Record 35 of Set 5 | matoury
# Processing Record 36 of Set 5 | pisco
# Processing Record 37 of Set 5 | barcelos
# Processing Record 38 of Set 5 | espargos
# City not found. Skipping...
# Processing Record 39 of Set 5 | znamenskoye
# Processing Record 40 of Set 5 | watertown
# Processing Record 41 of Set 5 | ambovombe
# Processing Record 42 of Set 5 | tazovsky
# Processing Record 43 of Set 5 | riverside
# Processing Record 44 of Set 5 | sinop
# Processing Record 45 of Set 5 | socorro
# Processing Record 46 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 47 of Set 5 | ustka
# Processing Record 48 of Set 5 | okha
# Processing Record 49 of Set 5 | lerwick
# Processing Record 0 of Set 6 | bel ombre
# Processing Record 1 of Set 6 | dudinka
# Processing Record 2 of Set 6 | josenii bargaului
# Processing Record 3 of Set 6 | praia da vitoria
# Processing Record 4 of Set 6 | villa bruzual
# Processing Record 5 of Set 6 | kailua-kona
# Processing Record 6 of Set 6 | hilo
# Processing Record 7 of Set 6 | tucuma
# Processing Record 8 of Set 6 | bac lieu
# Processing Record 9 of Set 6 | nemuro
# Processing Record 10 of Set 6 | sur
# Processing Record 11 of Set 6 | tevragh zeina
# City not found. Skipping...
# Processing Record 12 of Set 6 | inarajan village
# Processing Record 13 of Set 6 | arvayheer
# Processing Record 14 of Set 6 | luang namtha
# Processing Record 15 of Set 6 | gumdag
# Processing Record 16 of Set 6 | nuzvid
# Processing Record 17 of Set 6 | coron
# Processing Record 18 of Set 6 | hithadhoo
# Processing Record 19 of Set 6 | mana
# Processing Record 20 of Set 6 | la passe
# Processing Record 21 of Set 6 | kansanshi
# Processing Record 22 of Set 6 | ha'il
# Processing Record 23 of Set 6 | geraldton
# Processing Record 24 of Set 6 | pandan
# Processing Record 25 of Set 6 | mhamid
# Processing Record 26 of Set 6 | buka
# Processing Record 27 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 28 of Set 6 | tobelo
# Processing Record 29 of Set 6 | bechar
# Processing Record 30 of Set 6 | dryden
# Processing Record 31 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 6 | san angelo
# Processing Record 33 of Set 6 | shira
# Processing Record 34 of Set 6 | aktau
# Processing Record 35 of Set 6 | amursk
# Processing Record 36 of Set 6 | baise city
# Processing Record 37 of Set 6 | ar ruways
# Processing Record 38 of Set 6 | creston
# Processing Record 39 of Set 6 | nyala
# Processing Record 40 of Set 6 | tranqueras
# Processing Record 41 of Set 6 | nar'yan-mar
# Processing Record 42 of Set 6 | usinsk
# Processing Record 43 of Set 6 | tazacorte
# Processing Record 44 of Set 6 | mogocha
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | cabo san lucas
# Processing Record 47 of Set 6 | vallenar
# Processing Record 48 of Set 6 | ixtapa
# Processing Record 49 of Set 6 | uturoa
# Processing Record 0 of Set 7 | nagqu
# Processing Record 1 of Set 7 | aguililla
# Processing Record 2 of Set 7 | tavda
# Processing Record 3 of Set 7 | thayetmyo
# Processing Record 4 of Set 7 | manatutu
# City not found. Skipping...
# Processing Record 5 of Set 7 | biryusinsk
# Processing Record 6 of Set 7 | lan krabue
# Processing Record 7 of Set 7 | swakopmund
# Processing Record 8 of Set 7 | mariestad
# Processing Record 9 of Set 7 | keflavik
# Processing Record 10 of Set 7 | port elizabeth
# Processing Record 11 of Set 7 | adamovka
# Processing Record 12 of Set 7 | namibe
# Processing Record 13 of Set 7 | tomatlan
# Processing Record 14 of Set 7 | squamish
# Processing Record 15 of Set 7 | ciudad lazaro cardenas
# Processing Record 16 of Set 7 | illizi
# Processing Record 17 of Set 7 | susuman
# Processing Record 18 of Set 7 | khorixas
# Processing Record 19 of Set 7 | vila franca do campo
# Processing Record 20 of Set 7 | la ronge
# Processing Record 21 of Set 7 | kill devil hills
# Processing Record 22 of Set 7 | vanimo
# Processing Record 23 of Set 7 | kolonia town
# Processing Record 24 of Set 7 | sudak
# Processing Record 25 of Set 7 | montepuez
# Processing Record 26 of Set 7 | persembe
# Processing Record 27 of Set 7 | iquitos
# Processing Record 28 of Set 7 | saposoa
# Processing Record 29 of Set 7 | fada
# Processing Record 30 of Set 7 | hamilton
# Processing Record 31 of Set 7 | acarau
# Processing Record 32 of Set 7 | sikasso
# Processing Record 33 of Set 7 | dosso
# Processing Record 34 of Set 7 | uaua
# Processing Record 35 of Set 7 | rongelap
# Processing Record 36 of Set 7 | beau vallon
# Processing Record 37 of Set 7 | lensk
# Processing Record 38 of Set 7 | badger
# Processing Record 9 of Set 9 | karratha
# Processing Record 10 of Set 9 | westport
# Processing Record 11 of Set 9 | mengyin
# Processing Record 12 of Set 9 | annotto bay
# Processing Record 13 of Set 9 | chiili
# City not found. Skipping...
# Processing Record 14 of Set 9 | rehoboth
# Processing Record 15 of Set 9 | tome acu
# Processing Record 16 of Set 9 | rabaul
# Processing Record 17 of Set 9 | mukah
# City not found. Skipping...
# Processing Record 18 of Set 9 | lubang
# Processing Record 19 of Set 9 | ahau
# City not found. Skipping...
# Processing Record 20 of Set 9 | myeik
# Processing Record 21 of Set 9 | pasuquin
# Processing Record 22 of Set 9 | pimenta bueno
# Processing Record 23 of Set 9 | beira
# Processing Record 24 of Set 9 | kitimat
# Processing Record 25 of Set 9 | haiku-pauwela
# Processing Record 26 of Set 9 | ndele
# Processing Record 27 of Set 9 | little cayman
# City not found. Skipping...
# Processing Record 28 of Set 9 | omagari
# Processing Record 29 of Set 9 | sitia
# Processing Record 30 of Set 9 | koh kong
# Processing Record 31 of Set 9 | llucmajor
# Processing Record 32 of Set 9 | hola
# Processing Record 33 of Set 9 | timbiqui
# Processing Record 34 of Set 9 | valday
# Processing Record 35 of Set 9 | dawson creek
# Processing Record 36 of Set 9 | duong dong
# Processing Record 37 of Set 9 | taroa
# Processing Record 38 of Set 9 | wheelersburg
# Processing Record 39 of Set 9 | kwadukuza
# Processing Record 40 of Set 9 | natal
# Processing Record 41 of Set 9 | kismayo
# Processing Record 42 of Set 9 | toga village
# City not found. Skipping...
# Processing Record 43 of Set 9 | vorkuta
# Processing Record 44 of Set 9 | qarazhal
# Processing Record 45 of Set 9 | manokwari
# Processing Record 46 of Set 9 | tarauaca
# Processing Record 47 of Set 9 | kudahuvadhoo
# Processing Record 48 of Set 9 | hilvan
# Processing Record 49 of Set 9 | novyy oskol
# Processing Record 0 of Set 10 | jalai nur
# Processing Record 1 of Set 10 | aykhal
# Processing Record 2 of Set 10 | san antonio de pale
# Processing Record 3 of Set 10 | mumford
# Processing Record 4 of Set 10 | sarkand
# Processing Record 5 of Set 10 | cozumel
# Processing Record 6 of Set 10 | richards bay
# Processing Record 7 of Set 10 | bu'aale
# Processing Record 8 of Set 10 | lagunas
# Processing Record 9 of Set 10 | cantonment
# Processing Record 10 of Set 10 | morondava
# Processing Record 11 of Set 10 | mongo
# Processing Record 12 of Set 10 | inirida
# Processing Record 13 of Set 10 | port moresby
# Processing Record 14 of Set 10 | saint-pierre
# Processing Record 15 of Set 10 | kayes
# Processing Record 16 of Set 10 | kayangel
# Processing Record 17 of Set 10 | saudarkrokur
# Processing Record 18 of Set 10 | el granada
# Processing Record 19 of Set 10 | strensall
# Processing Record 20 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 21 of Set 10 | parang
# Processing Record 22 of Set 10 | sassandra
# Processing Record 23 of Set 10 | selfoss
# Processing Record 24 of Set 10 | sampit
# Processing Record 25 of Set 10 | butte
# Processing Record 26 of Set 10 | novaya igirma
# Processing Record 27 of Set 10 | bianzhuang
# Processing Record 28 of Set 10 | sayan
# Processing Record 29 of Set 10 | arkalyk
# Processing Record 30 of Set 10 | puerto deseado
# Processing Record 31 of Set 10 | pangody
# Processing Record 32 of Set 10 | tachov
# Processing Record 33 of Set 10 | bantogon
# Processing Record 34 of Set 10 | owen sound
# Processing Record 35 of Set 10 | mpraeso
# Processing Record 36 of Set 10 | plettenberg bay
# Processing Record 37 of Set 10 | barra de santo antonio
# Processing Record 38 of Set 10 | srivardhan
# Processing Record 39 of Set 10 | rio grande
# Processing Record 40 of Set 10 | ust-tsilma
# Processing Record 41 of Set 10 | argo
# Processing Record 42 of Set 10 | ko pha ngan
# Processing Record 43 of Set 10 | turan
# Processing Record 44 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 45 of Set 10 | colares
# Processing Record 46 of Set 10 | fonadhoo
# City not found. Skipping...
# Processing Record 47 of Set 10 | chanda
# Processing Record 48 of Set 10 | jinchang
# Processing Record 49 of Set 10 | ouargaye
# Processing Record 0 of Set 11 | christchurch
# Processing Record 1 of Set 11 | agios nikolaos
# Processing Record 2 of Set 11 | mahibadhoo
# Processing Record 3 of Set 11 | tanda
# Processing Record 4 of Set 11 | callao
# Processing Record 5 of Set 11 | hastings
# Processing Record 6 of Set 11 | ludza
# Processing Record 7 of Set 11 | n'zeto
# Processing Record 8 of Set 11 | zouerate
# Processing Record 9 of Set 11 | prabumulih
# Processing Record 10 of Set 11 | konkwesso
# Processing Record 11 of Set 11 | noshiro
# Processing Record 12 of Set 11 | gulf breeze
# Processing Record 13 of Set 11 | chudey
# Processing Record 14 of Set 11 | ocean city
# Processing Record 15 of Set 11 | chita
# Processing Record 16 of Set 11 | nova sintra
# Processing Record 17 of Set 11 | lorengau
# Processing Record 18 of Set 11 | achinsk
# Processing Record 19 of Set 11 | 'ohonua
# City not found. Skipping...
# Processing Record 20 of Set 11 | eynesil
# Processing Record 21 of Set 11 | brisas de zicatela
# Processing Record 22 of Set 11 | oakdale
# Processing Record 23 of Set 11 | bahia honda
# Processing Record 24 of Set 11 | brookings
# Processing Record 25 of Set 11 | vengurla
# Processing Record 26 of Set 11 | revelstoke
# Processing Record 27 of Set 11 | coquimbo
# Processing Record 28 of Set 11 | tangalle
# Processing Record 29 of Set 11 | kruisfontein
# Processing Record 30 of Set 11 | sunne
# Processing Record 31 of Set 11 | el jadid
# Processing Record 32 of Set 11 | polyarnyy
# Processing Record 33 of Set 11 | hsinchu
# Processing Record 34 of Set 11 | howrah
# Processing Record 35 of Set 11 | snowflake
# Processing Record 36 of Set 11 | barclayville
# Processing Record 37 of Set 11 | timaru
# Processing Record 38 of Set 11 | guerrero negro
# Processing Record 39 of Set 11 | new norfolk
# Processing Record 40 of Set 11 | gamboma
# Processing Record 41 of Set 11 | kone
# Processing Record 42 of Set 11 | lautoka
# Processing Record 43 of Set 11 | ulsteinvik
# Processing Record 44 of Set 11 | paita
# Processing Record 45 of Set 11 | murzuq
# Processing Record 46 of Set 11 | diego de almagro
# Processing Record 47 of Set 11 | qamdo
# Processing Record 48 of Set 11 | codrington
# Processing Record 49 of Set 11 | myskhako
# Processing Record 0 of Set 12 | hotan
# Processing Record 1 of Set 12 | fortaleza
# Processing Record 2 of Set 12 | san francisco telixtlahuaca
# Processing Record 3 of Set 12 | flin flon
# Processing Record 4 of Set 12 | ambikapur
# Processing Record 5 of Set 12 | rasra
# Processing Record 6 of Set 12 | swift current
# Processing Record 7 of Set 12 | skikda
# Processing Record 8 of Set 12 | suntar
# Processing Record 9 of Set 12 | port isabel
# Processing Record 10 of Set 12 | brigantine
# Processing Record 11 of Set 12 | rapar
# Processing Record 12 of Set 12 | klaksvik
# Processing Record 13 of Set 12 | kasongo-lunda
# Processing Record 14 of Set 12 | adh dhibiyah
# City not found. Skipping...
# Processing Record 15 of Set 12 | papa
# Processing Record 16 of Set 12 | baissa
# Processing Record 17 of Set 12 | petrov val
# Processing Record 18 of Set 12 | nova vicosa
# Processing Record 19 of Set 12 | gargalianoi
# Processing Record 20 of Set 12 | sambava
# Processing Record 21 of Set 12 | seaside
# Processing Record 22 of Set 12 | altai
# Processing Record 23 of Set 12 | shache
# Processing Record 24 of Set 12 | nong bua
# Processing Record 25 of Set 12 | strelka
# Processing Record 26 of Set 12 | marka
# Processing Record 27 of Set 12 | semirom
# Processing Record 28 of Set 12 | souillac
# Processing Record 29 of Set 12 | happy valley-goose bay
# Processing Record 30 of Set 12 | jinghong
# Processing Record 31 of Set 12 | kichmengskiy gorodok
# Processing Record 32 of Set 12 | awjilah
# Processing Record 33 of Set 12 | devils lake
# Processing Record 34 of Set 12 | praya
# Processing Record 35 of Set 12 | kooringal
# Processing Record 36 of Set 12 | warmbad
# Processing Record 37 of Set 12 | yarega
# Processing Record 38 of Set 12 | mossel bay
# Processing Record 39 of Set 12 | mossendjo
# Processing Record 40 of Set 12 | muravlenko
# Processing Record 41 of Set 12 | wenchang
# Processing Record 42 of Set 12 | sao miguel do araguaia
# Processing Record 43 of Set 12 | el calafate
# Processing Record 44 of Set 12 | lae
# Processing Record 45 of Set 12 | kigonsera
# Processing Record 46 of Set 12 | daru
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          574
# Lat           574
# Lng           574
# Max Temp      574
# Humidity      574
# Cloudiness    574
# Wind Speed    574
# Country       574
# Date          574
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        waitangi -43.9535 -176.5597    283.05        95          93
# 1  ribeira grande  38.5167  -28.7000    294.14        77          40
# 2     olonkinbyen  70.9221   -8.7187    274.98        77         100
# 3       adamstown -25.0660 -130.1015    293.15        76           6
# 4       grytviken -54.2811  -36.5092    272.59        67           7
#
#    Wind Speed Country        Date
# 0        1.34      NZ  1696708686
# 1        8.23      PT  1696708720
# 2        6.90      SJ  1696708666
# 3        5.52      PN  1696708909
# 4        5.50      GS  1696708758

# %%
# Export the City_Data into a CSV
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              waitangi -43.9535 -176.5597    283.05        95          93
# 1        ribeira grande  38.5167  -28.7000    294.14        77          40
# 2           olonkinbyen  70.9221   -8.7187    274.98        77         100
# 3             adamstown -25.0660 -130.1015    293.15        76           6
# 4             grytviken -54.2811  -36.5092    272.59        67           7
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      NZ  1696708686
# 1              8.23      PT  1696708720
# 2              6.90      SJ  1696708666
# 3              5.52      PN  1696708909
# 4              5.50      GS  1696708758

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], color='blue', alpha=0.7)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")  
plt.title("Latitude vs. Temperature")
plt.grid(True)


# Incorporate the other graph properties
cbar = plt.colorbar()
cbar.set_label("Max Temperature (°C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], color='green', alpha=0.7)
plt.xlabel("Latitude")
plt.ylabel("Humidity")  
plt.title("Latitude vs.Humidity")
plt.grid(True)

# Incorporate the other graph properties
cbar = plt.colorbar()
cbar.set_label("Humidity")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], color='gray', alpha=0.7, edgecolors='black', linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs. Cloudiness")
plt.grid(True)
# Incorporate the other graph properties
plt.xticks(range(-90, 91, 10)) 
plt.yticks(range(0, 101, 20))  
plt.xlim(-90, 90)  
plt.ylim(0, 100)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(8, 6))
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], color='purple', alpha=0.7, edgecolors='black', linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Latitude vs. Wind Speed")
plt.grid(True)

# Incorporate the other graph properties
plt.xticks(range(-90, 91, 10))  
plt.yticks(range(0, int(city_data_df["Wind Speed"].max()) + 1, 5)) 
plt.xlim(-90, 90)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def plot_linear_regression(x_values, y_values, x_label, y_label, title, text_coordinates):
    slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
    
    regress_values = x_values * slope + intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]


# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        ribeira grande  38.5167  -28.7000    294.14        77          40
# 2           olonkinbyen  70.9221   -8.7187    274.98        77         100
# 9              enewetak  11.3474  162.3373    302.34        74          74
# 10           port blair  11.6667   92.7500    299.17        89         100
# 13               forest  37.3638  -79.2897    292.55        43           0
#
#          Wind Speed Country        Date
# City_ID
# 1              8.23      PT  1696708720
# 2              6.90      SJ  1696708666
# 9              8.08      MH  1696708676
# 10             3.09      IN  1696708913
# 13             0.45      US  1696708915

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 waitangi -43.9535 -176.5597    283.05        95          93
# 3                adamstown -25.0660 -130.1015    293.15        76           6
# 4                grytviken -54.2811  -36.5092    272.59        67           7
# 5               vila velha -20.3297  -40.2925    301.12        80           0
# 6        port-aux-francais -49.3500   70.2167    275.85        79          98
#
#          Wind Speed Country        Date
# City_ID
# 0              1.34      NZ  1696708686
# 3              5.52      PN  1696708909
# 4              5.50      GS  1696708758
# 5              8.75      BR  1696708910
# 6             12.43      TF  1696708911

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope, intercept, r_value, p_value, std_err = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values, y_values, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values, regress_values, color='red')
line_eq = f"y = {slope:.2f}x + {intercept:.2f}\nR² = {r_value**2:.2f}"
plt.annotate(line_eq, (10, 20), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.title("Northern Hemisphere - Temperature vs. Latitude Linear Regression")
plt.grid(True)
plt.show()

# %%
# Linear regression on Southern Hemisphere
x_values_south = southern_hemi_df["Lat"]
y_values_south = southern_hemi_df["Max Temp"]
slope_south, intercept_south, r_value_south, p_value_south, std_err_south = linregress(x_values_south, y_values_south)
regress_values_south = x_values_south * slope_south + intercept_south

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values_south, y_values_south, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values_south, regress_values_south, color='red')
line_eq_south = f"y = {slope_south:.2f}x + {intercept_south:.2f}\nR² = {r_value_south**2:.2f}"
plt.annotate(line_eq_south, (-50, 35), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (°C)")
plt.title("Southern Hemisphere - Temperature vs. Latitude Linear Regression")
plt.grid(True)
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** As a result, there is a negative correlation between latitude and temperature in the Northern Hemisphere. This means that as latitude decreases (approaching the equator), the temperature tends to rise. As latitude increases (approaching the equator), the temperature tends to rise. This pattern is reflected in the positive slope of the linear regression line in the Southern Hemisphere temperature vs. latitude plot.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Extract data for humidity vs. latitude in the Northern Hemisphere
x_values_hum_north = northern_hemi_df["Lat"]
y_values_hum_north = northern_hemi_df["Humidity"]
slope_hum_north, intercept_hum_north, r_value_hum_north, p_value_hum_north, std_err_hum_north = linregress(x_values_hum_north, y_values_hum_north)
regress_values_hum_north = x_values_hum_north * slope_hum_north + intercept_hum_north

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values_hum_north, y_values_hum_north, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values_hum_north, regress_values_hum_north, color='red')
line_eq_hum_north = f"y = {slope_hum_north:.2f}x + {intercept_hum_north:.2f}\nR² = {r_value_hum_north**2:.2f}"
plt.annotate(line_eq_hum_north, (45, 10), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.grid(True)
plt.show()
print(f"Linear Regression Equation (Northern Hemisphere - Humidity vs. Latitude): {line_eq_hum_north}")
print(f"R-squared: {r_value_hum_north**2:.2f}")
print(f"P-value: {p_value_hum_north:.2f}")
# Out:
# Linear Regression Equation (Northern Hemisphere - Humidity vs. Latitude): y = 0.06x + 69.16
# R² = 0.00
# R-squared: 0.00
# P-value: 0.25

# %%
# Southern Hemisphere
# Extract data for humidity vs. latitude in the Southern Hemisphere
x_values_hum_south = southern_hemi_df["Lat"]
y_values_hum_south = southern_hemi_df["Humidity"]

# Perform linear regression for Southern Hemisphere
slope_hum_south, intercept_hum_south, r_value_hum_south, p_value_hum_south, std_err_hum_south = linregress(x_values_hum_south, y_values_hum_south)

# Create regression line for Southern Hemisphere
regress_values_hum_south = x_values_hum_south * slope_hum_south + intercept_hum_south

# Create the scatter plot for Southern Hemisphere
plt.figure(figsize=(8, 6))
plt.scatter(x_values_hum_south, y_values_hum_south, color='b', alpha=0.7, edgecolors='black', linewidth=1)

# Plot regression line for Southern Hemisphere
plt.plot(x_values_hum_south, regress_values_hum_south, color='red')

# Annotate the linear regression for Southern Hemisphere
line_eq_hum_south = f"y = {slope_hum_south:.2f}x + {intercept_hum_south:.2f}\nR² = {r_value_hum_south**2:.2f}"
plt.annotate(line_eq_hum_south, (-55, 20), fontsize=15, color='red')

# scatter plot
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression")
plt.grid(True)
plt.show()

print(f"Linear Regression Equation (Southern Hemisphere - Humidity vs. Latitude): {line_eq_hum_south}")
print(f"R-squared: {r_value_hum_south**2:.2f}")
print(f"P-value: {p_value_hum_south:.2f}")
# Out:
# Linear Regression Equation (Southern Hemisphere - Humidity vs. Latitude): y = -0.05x + 69.34
# R² = 0.00
# R-squared: 0.00
# P-value: 0.63

# %% [markdown]
# **Discussion about the linear relationship:** the relationship is not statistically significant. This means that there is essentially no meaningful linear relationship between humidity and latitude in the Northern Hemisphere. Similarly, in the Southern Hemisphere indicates a slight negative slope in the relationship between humidity and latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values_hum_north = northern_hemi_df["Lat"]
y_values_hum_north = northern_hemi_df["Cloudiness"]
slope_hum_north, intercept_hum_north, r_value_hum_north, p_value_hum_north, std_err_hum_north = linregress(x_values_hum_north, y_values_hum_north)
regress_values_hum_north = x_values_hum_north * slope_hum_north + intercept_hum_north

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values_hum_north, y_values_hum_north, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values_hum_north, regress_values_hum_north, color='red')
line_eq_hum_north = f"y = {slope_hum_north:.2f}x + {intercept_hum_north:.2f}\nR² = {r_value_hum_north**2:.2f}"
plt.annotate(line_eq_hum_north, (45, 10), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.grid(True)
plt.show()
print(f"Linear Regression Equation (Northern Hemisphere -Cloudiness vs. Latitude): {line_eq_hum_north}")
print(f"R-squared: {r_value_hum_north**2:.2f}")
print(f"P-value: {p_value_hum_north:.2f}")
# Out:
# Linear Regression Equation (Northern Hemisphere -Cloudiness vs. Latitude): y = 0.11x + 58.04
# R² = 0.00
# R-squared: 0.00
# P-value: 0.28

# %%
# Southern Hemisphere
x_values_south = southern_hemi_df["Lat"]
y_values_south = southern_hemi_df["Cloudiness"]
slope_south, intercept_south, r_value_south, p_value_south, std_err_south = linregress(x_values_south, y_values_south)
regress_values_south = x_values_south * slope_south + intercept_south

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values_south, y_values_south, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values_south, regress_values_south, color='red')
line_eq_south = f"y = {slope_south:.2f}x + {intercept_south:.2f}\nR² = {r_value_south**2:.2f}"
plt.annotate(line_eq_south, (-50, 35), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression")
plt.grid(True)
plt.show()
print(f"Linear Regression Equation (Southern Hemisphere - Cloudiness vs. Latitude): {line_eq_hum_south}")
print(f"R-squared: {r_value_hum_south**2:.2f}")
print(f"P-value: {p_value_hum_south:.2f}")
# Out:
# Linear Regression Equation (Southern Hemisphere - Cloudiness vs. Latitude): y = -0.05x + 69.34
# R² = 0.00
# R-squared: 0.00
# P-value: 0.63

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear regression analyses for both cloudiness and latitude in both the Northern and Southern Hemispheres show no correlations.In the Northern Hemisphere theres a very slight positive slope, indicating a minimal increase in cloudiness with latitude, and the p-value of 0.28 indicates non-significance. southern hemisphere indicates no significance as well. Overall, these results shows that latitude alone does not serve as a reliable predictor for cloudiness in either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values_hum_north = northern_hemi_df["Lat"]
y_values_hum_north = northern_hemi_df["Wind Speed"]
slope_hum_north, intercept_hum_north, r_value_hum_north, p_value_hum_north, std_err_hum_north = linregress(x_values_hum_north, y_values_hum_north)
regress_values_hum_north = x_values_hum_north * slope_hum_north + intercept_hum_north

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values_hum_north, y_values_hum_north, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values_hum_north, regress_values_hum_north, color='red')
line_eq_hum_north = f"y = {slope_hum_north:.2f}x + {intercept_hum_north:.2f}\nR² = {r_value_hum_north**2:.2f}"
plt.annotate(line_eq_hum_north, (45, 10), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(%)")
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.grid(True)
plt.show()
print(f"Linear Regression Equation (Northern Hemisphere -Wind Speed vs. Latitude): {line_eq_hum_north}")
print(f"R-squared: {r_value_hum_north**2:.2f}")
print(f"P-value: {p_value_hum_north:.2f}")
# Out:
# Linear Regression Equation (Northern Hemisphere -Wind Speed vs. Latitude): y = 0.02x + 2.78
# R² = 0.03
# R-squared: 0.03
# P-value: 0.00

# %%
# Southern Hemisphere
x_values_south = southern_hemi_df["Lat"]
y_values_south = southern_hemi_df["Wind Speed"]
slope_south, intercept_south, r_value_south, p_value_south, std_err_south = linregress(x_values_south, y_values_south)
regress_values_south = x_values_south * slope_south + intercept_south

#scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x_values_south, y_values_south, color='b', alpha=0.7, edgecolors='black', linewidth=1)
plt.plot(x_values_south, regress_values_south, color='red')
line_eq_south = f"y = {slope_south:.2f}x + {intercept_south:.2f}\nR² = {r_value_south**2:.2f}"
plt.annotate(line_eq_south, (-50, 35), fontsize=15, color='red')
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression")
plt.grid(True)
plt.show()
print(f"Linear Regression Equation (Southern Hemisphere - Wind Speed vs. Latitude): {line_eq_hum_south}")
print(f"R-squared: {r_value_hum_south**2:.2f}")
print(f"P-value: {p_value_hum_south:.2f}")
# Out:
# Linear Regression Equation (Southern Hemisphere - Wind Speed vs. Latitude): y = -0.05x + 69.34
# R² = 0.00
# R-squared: 0.00
# P-value: 0.63

# %% [markdown]
# **Discussion about the linear relationship:** The latitude has a very limited effect on wind speed. There is no significant relation
